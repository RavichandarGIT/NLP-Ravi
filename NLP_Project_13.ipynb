# %% [markdown]
# <a href="https://colab.research.google.com/github/RavichandarGIT/NLP-Ravi/blob/main/NLP_Project_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

# Graph representation
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}

# Heuristic values (estimated distance to goal F)
heuristic = {
    'A': 6,
    'B': 4,
    'C': 2,
    'D': 5,
    'E': 3,
    'F': 0
}

def best_first_search(start, goal):
    visited = set()
    priority_queue = []

    heapq.heappush(priority_queue, (heuristic[start], start))
    path = []

    while priority_queue:
        h, node = heapq.heappop(priority_queue)

        if node not in visited:
            visited.add(node)
            path.append(node)

            if node == goal:
                print("Goal Reached!")
                print("Path:", " -> ".join(path))
                print("Heuristic Cost:", h)
                return

            for neighbor in graph[node]:
                if neighbor not in visited:
                    heapq.heappush(priority_queue, (heuristic[neighbor], neighbor))

    print("Goal not reachable")

# Run the algorithm
best_first_search('A', 'F')
# Out:
# Goal Reached!
# Path: A -> C -> F
# Heuristic Cost: 0
