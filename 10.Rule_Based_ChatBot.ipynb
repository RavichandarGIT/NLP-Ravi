# %%
import re
import random

patterns = {
    r'hi|hello|hey': [
        "Hello!",
        "Hi there!",
        "Hey! How can I help you?"
    ],

    r'how are you': [
        "I am fine!",
        "Doing great!",
        "I am here to help you."
    ],

    r'what is your name': [
        "I am an NLP Chatbot.",
        "You can call me NLP Bot."
    ],

    r'bye|exit': [
        "Goodbye!",
        "See you soon!",
        "Have a great day!"
    ]
}

def chatbot_response(user_input):
    user_input = user_input.lower()

    for pattern, responses in patterns.items():1
        if re.search(pattern, user_input):
            return random.choice(responses)

    return "Sorry, I don't understand that."

# Chat loop
while True:
    user_input = input("You: ")
    if re.search(r'\b(bye|exit)\b', user_input.lower()):
        print("Bot:", chatbot_response(user_input))
        break
    print("Bot:", chatbot_response(user_input))
# Out:
# You:  hi
# Bot: Hey! How can I help you?
# You:  bye
# Bot: See you soon!
